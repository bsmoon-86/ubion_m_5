# %%
## seaborn 라이브러리 설치 
# !pip install seaborn

# %%
# 라이브러리 로드 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## matplotlib을 이용한 그래프의 시각화 
# 라인 그래프 (플롯 그래프)
# y축의 데이터만 존재하는 경우
# x축의 데이터는 0부터 시작해서 1씩 증가하는 형태로 생성
y_list = [10, 5, 8, 16]
plt.plot(y_list)
# show() : print() 같은 기능
plt.show()

# %%
# x, y축의 데이터가 모두 존재하는 경우 
x_list = [1, 3, 6, 10]
y_list = [1,2,3,4]
plt.plot(x_list, y_list)
plt.show()

# %%
# 라인 그래프의 라인의 색상과 종류를 변경
plt.plot(x_list, y_list, '#FF0077')
plt.show()

# %%
plt.plot(x_list, y_list, '--')
plt.show()

# %%
plt.plot([1,2,3,4], [10, 20, 10, 30])
plt.plot([1,3,5,7], [20, 40, 8, 1])
# x축에 라벨링 
plt.xlabel('X')
# y축 라벨링
plt.ylabel('Y')
# 그래프의 이름 표시 
plt.title('그래프')
# 범례 추가 
plt.legend(['a', 'b'])
plt.show()
# Out:
# C:\Users\EZEN\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\EZEN\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\EZEN\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
## 그래프를 출력할때 한글이 깨진다. 
## matplotlib에서 사용하는 폰트를 변경하는 코드는 실행
# windows와 MAC은 사용하는 폰트가 다르다.

# %%
import platform

# %%
## 한글 깨짐 방지
if platform.system() == 'Darwin':
    plt.rc('font', family = 'AppleGothic')
else :
    plt.rc('font', family = 'Malgun Gothic')

# %%
plt.plot([1,2,3,4], [10, 20, 10, 30], label='A')
plt.plot([1,3,5,7], [20, 40, 8, 1], label='B')
# x축에 라벨링 
plt.xlabel('X')
# y축 라벨링
plt.ylabel('Y')
# 그래프의 이름 표시 
plt.title('그래프')
# 범례 추가 
plt.legend()
plt.show()

# %%
# 막대 그래프 
x = [1,2,3,4]
y = [80, 70, 90, 75]

plt.bar(x, y)
plt.show()

# %%
plt.barh(x, y)
plt.show()

# %%
# 옵션 추가 (색상, 너비 변경)
plt.bar(x, y, width=0.2, color= ['r', 'b'])
plt.show()

# %%
# 특정 막대의 색상을 변경
graph = plt.bar(x, y)
graph[2].set_color('r')
plt.show()

# %%
# 산점도 그래프 
x = np.random.random(30)
y = np.random.random(30)

x
# Out:
# array([0.72735403, 0.38035305, 0.9925873 , 0.82741834, 0.6410522 ,
#        0.05547911, 0.20559074, 0.67862959, 0.8284588 , 0.00593582,
#        0.36853955, 0.96685048, 0.63586502, 0.49864822, 0.74333204,
#        0.28179457, 0.44520905, 0.16431266, 0.38576537, 0.32762617,
#        0.71157803, 0.60347727, 0.02293612, 0.83885403, 0.94227511,
#        0.30041144, 0.69513663, 0.07046879, 0.81109007, 0.40006728])

# %%
plt.scatter(x, y)
plt.show()

# %%
df = pd.read_csv("../../csv/drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# 맥주소비량, 위스키소비량, 와인의 소비량, 순수 알콜의 양의 
# 상관 관계 확인
# 상관 계수 : -1 ~ 1
    # -1 : 하나의 데이터가 오르면 나머지 하나의 데이터는 내려간다. 
    # 1 : 하나의 데이터가 오르면 나머지 하나의 데이터도 같이 오른다. 
    # 0 : 두 개의 데이터가 무작위
# DataFrame 안에 있는 corr() 함수 호출
corr = df[ ['beer_servings', 'spirit_servings', 'wine_servings',
     'total_litres_of_pure_alcohol'] ].corr('pearson')

# %%
# seaborn 라이브러리를 이용하여 히트맵 시각화
cols = ['beer', 'spirit', 'wine', 'alcohol']

hm = sns.heatmap(
    corr.values, 
    cbar = True,    # 사이드바 표시 
    annot = True,   # 히트맵에 숫자를 표시 
    square= True,   # 정사각형 표시
    fmt = '0.3f',   # 숫자의 소수점 자리수
    annot_kws = {'size' : 20}, # 숫자의 크기 
    xticklabels= cols, 
    yticklabels= cols
)

plt.show()

# %%
a = sns.pairplot(
    df.loc[:, 'beer_servings' : 'total_litres_of_pure_alcohol'], 
    height = 2.5, 
    kind = 'reg'
)
plt.show()
# Out:
# c:\Users\EZEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import numpy as np

# %%
np.polyfit(df['spirit_servings'], df['beer_servings'], 1)
# Out:
# array([ 0.52564678, 63.5859561 ])
